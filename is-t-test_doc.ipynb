# %% [raw]
# ---
# title: Hypothesis Testing with Independent-Samples *t*-tests
# subtitle: PSY 241
# format:
#   html:
#     html-math-method: mathjax
#     code-fold: true
#     axe:
#       output: console
#     self-contained-math: true
#     embed-resources: false
#
# ---

# %%
#| echo: false
import importlib
import stats_project # Replace with your module name

importlib.reload(stats_project)
from stats_project import RandomData # Re-import the specific class

# %%
#| echo: false
#| output: asis
from stats_project import RandomData

RandomData(groups = 2, n = 8).independent_samples_t_test()
# Out:
# Given the following between-subjects data, is the mean of $Group_A$ significantly greater than the mean of $Group_B$?  Use a ${1}$ tailed-test with $\alpha = {0.01}$<br><br>
# <style type="text/css">
# </style>
# <table id="T_93b18">
#   <thead>
#     <tr>
#       <th id="T_93b18_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_93b18_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_93b18_row0_col0" class="data row0 col0" >30</td>
#       <td id="T_93b18_row0_col1" class="data row0 col1" >54</td>
#     </tr>
#     <tr>
#       <td id="T_93b18_row1_col0" class="data row1 col0" >24</td>
#       <td id="T_93b18_row1_col1" class="data row1 col1" >37</td>
#     </tr>
#     <tr>
#       <td id="T_93b18_row2_col0" class="data row2 col0" >36</td>
#       <td id="T_93b18_row2_col1" class="data row2 col1" >38</td>
#     </tr>
#     <tr>
#       <td id="T_93b18_row3_col0" class="data row3 col0" >36</td>
#       <td id="T_93b18_row3_col1" class="data row3 col1" >29</td>
#     </tr>
#     <tr>
#       <td id="T_93b18_row4_col0" class="data row4 col0" >45</td>
#       <td id="T_93b18_row4_col1" class="data row4 col1" >32</td>
#     </tr>
#     <tr>
#       <td id="T_93b18_row5_col0" class="data row5 col0" >34</td>
#       <td id="T_93b18_row5_col1" class="data row5 col1" >15</td>
#     </tr>
#     <tr>
#       <td id="T_93b18_row6_col0" class="data row6 col0" >27</td>
#       <td id="T_93b18_row6_col1" class="data row6 col1" >35</td>
#     </tr>
#     <tr>
#       <td id="T_93b18_row7_col0" class="data row7 col0" >29</td>
#       <td id="T_93b18_row7_col1" class="data row7 col1" >29</td>
#     </tr>
#   </tbody>
# </table>
# <br> The necessary summary Statistis for these data:<br>
#                              $$M_A = {32.62}, M_B = {33.62}$$
#                              $$SS_A = {303.88}, SS_B = {839.88}$$
#                              $$n_A = {8}, n_B = {8}$$<br><br>
# Calculate the pooled variance: <br>
#                             $$s_p^2 = {\frac{SS_A + SS_B}{df_A + df_B}}$$ <br>
#                             $$s_p^2 = {\frac{303.88 + 839.88}{7 + 7}}$$ <br>
#                             $$s_p^2 = \frac{1143.76}{14}$$ <br>
#                             $$s_p^2 = {81.7}$$ <br><br>
# Calculate the estimated error of the difference between means: $s_{(M_A - M_B)}$ <br>
#                             $$s_{(M_A - M_B)} = \sqrt{\frac{s_p^2}{n_1} + \frac{s_p^2}{n_1}}$$ <br>
#                             $$s_{(M_A - M_B)} = \sqrt{\frac{81.7}{8} + \frac{81.7}{8}}$$ <br>
#                             $$s_{(M_A - M_B)} = \sqrt{10.21 + 10.21}$$ <br>
#                             $$s_{(M_A - M_B)} = \sqrt{20.42}$$ <br>
#                             $$s_{(M_A - M_B)} = {4.52}$$ <br><br>
# Calculate $t_{obt}$ <br>
#                             $$t_{obt} = {\frac{(M_A - M_B) - (\mu_A - \mu_B)}{s_{(M_A - M_B)}}}$$ <br>
#                             $$t_{obt} = \frac{(32.62 - 33.62) - {0}}{4.52}$$ <br>
#                             $$t_{obt} = \frac{-1.0}{4.52}$$ <br>
#                             $$t_{obt} = {-0.22}$$ <br><br>
# Calculate Cohen's *d*  <br>
#                             $$d = \frac{M_A - M_B}{\sqrt{s_p^2}}$$ <br>
#                             $$d = \frac{(32.62 - 33.62)}{{{\sqrt{81.7}}}}$$ <br>
#                             $$d = \frac{(-1.0)}{9.04}$$ <br>
#                             $$d = {-0.11}$$ <br><br>
# The decision criteria: <br><br>
# $t_{crit} = +{2.62}, \alpha_{one-tailed} = {0.01}, df = {14}$<br><br>
# The results: <br><br>
# fail to reject the null hypothesis, results not significant, *t*(14) = -0.22, *p* > 0.01, *d* = -0.11<br><br>
