# %% [raw]
# ---
# title: Hypothesis Testing with z-Scores
# subtitle: PSY 241
# format:
#   html:
#     html-math-method: mathjax
#     code-fold: true
#     axe:
#       output: console
#     self-contained-math: true
#     embed-resources: true
#
# ---

# %%
#| echo: false
import importlib
import stats_project # Replace with your module name

importlib.reload(stats_project)
from stats_project import RandomData # Re-import the specific class

# %%
#| echo: false
#| output: asis
from stats_project import RandomData

RandomData(groups = 1, n = 8).z_test()
# Out:
# Given the following data, is the mean of $Group_A$ significantly greater than the population mean: $\mu = {36}$?<br><br>Use a ${1}$ tailed-test with $\alpha = {0.05}$<br><br>
# <style type="text/css">
# </style>
# <table id="T_ce48c">
#   <thead>
#     <tr>
#       <th id="T_ce48c_level0_col0" class="col_heading level0 col0" >A</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ce48c_row0_col0" class="data row0 col0" >52</td>
#     </tr>
#     <tr>
#       <td id="T_ce48c_row1_col0" class="data row1 col0" >70</td>
#     </tr>
#     <tr>
#       <td id="T_ce48c_row2_col0" class="data row2 col0" >72</td>
#     </tr>
#     <tr>
#       <td id="T_ce48c_row3_col0" class="data row3 col0" >48</td>
#     </tr>
#     <tr>
#       <td id="T_ce48c_row4_col0" class="data row4 col0" >47</td>
#     </tr>
#     <tr>
#       <td id="T_ce48c_row5_col0" class="data row5 col0" >23</td>
#     </tr>
#     <tr>
#       <td id="T_ce48c_row6_col0" class="data row6 col0" >39</td>
#     </tr>
#     <tr>
#       <td id="T_ce48c_row7_col0" class="data row7 col0" >27</td>
#     </tr>
#   </tbody>
# </table>
# <br>The necessary summary statistics for these data<br>
#                             $$M_A = {47.25}$$
#                             $${\sigma} = {16}$$
#                             $$n = {8}$$<br><br>
# Calculate the standard error <br>
#                             $$\sigma_M = \frac{\sigma}{\sqrt{N}}$$ <br>
#                             $$\sigma_M = \frac{16}{\sqrt8}$$ <br>
#                             $$\sigma_M = \frac{16}{2.83}$$ <br>
#                             $$\sigma_M = {5.65}$$ <br><br>
#                             Calculate $z_{obt}$ <br>
#                             $$z_{obt} = {\frac{M - \mu}{\sigma_M}}$$ <br>
#                             $$z_{obt} = \frac{47.25 - 36}{5.65}$$ <br>
#                             $$z_{obt} = \frac{11.25}{5.65}$$ <br>
#                             $$z_{obt} = {1.99}$$ <br><br>
#                             Calculate Cohen's d for effect size <br>
#                             $$d = \frac{M - \mu}{\sigma}$$ <br>
#                             $$d = \frac{47.25 - 36}{16}$$ <br>
#                             $$d = \frac{11.25}{16}$$ <br>
#                             $$d = {0.7}$$ <br><br>
# The decision criteria: <br><br>
# $z_{crit} = +{1.645}, \alpha_{one-tailed} = {0.05}$<br><br>
# The results: <br><br>
# reject the null hypothesis, results are significant, *z* = 1.99, *p* < 0.05, *d* = 0.7<br><br>
