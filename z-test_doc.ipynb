# %% [raw]
# ---
# title: Practice Problem - z-test
# subtitle: PSY 241
# format:
#   html:
#     html-math-method: mathjax
#     code-fold: true
#     axe:
#       output: console
#     self-contained-math: false
#     embed-resources: true
#
# ---

# %%
#| echo: false
import importlib
import stats_project # Replace with your module name

importlib.reload(stats_project)
from stats_project import RandomData # Re-import the specific class

# %%
#| echo: false
#| output: asis
from stats_project import RandomData

RandomData(groups = 1, n = 10).z_test()
# Out:
# Given the following data, is the mean of $Group_A$ significantly less than ${58}$?<br><br>Use a ${1}$ tailed-test with $\alpha = {0.01}$<br><br>
# <style type="text/css">
# </style>
# <table id="T_0873f">
#   <thead>
#     <tr>
#       <th id="T_0873f_level0_col0" class="col_heading level0 col0" >A</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0873f_row0_col0" class="data row0 col0" >104</td>
#     </tr>
#     <tr>
#       <td id="T_0873f_row1_col0" class="data row1 col0" >55</td>
#     </tr>
#     <tr>
#       <td id="T_0873f_row2_col0" class="data row2 col0" >79</td>
#     </tr>
#     <tr>
#       <td id="T_0873f_row3_col0" class="data row3 col0" >86</td>
#     </tr>
#     <tr>
#       <td id="T_0873f_row4_col0" class="data row4 col0" >121</td>
#     </tr>
#     <tr>
#       <td id="T_0873f_row5_col0" class="data row5 col0" >44</td>
#     </tr>
#     <tr>
#       <td id="T_0873f_row6_col0" class="data row6 col0" >86</td>
#     </tr>
#     <tr>
#       <td id="T_0873f_row7_col0" class="data row7 col0" >70</td>
#     </tr>
#     <tr>
#       <td id="T_0873f_row8_col0" class="data row8 col0" >115</td>
#     </tr>
#     <tr>
#       <td id="T_0873f_row9_col0" class="data row9 col0" >75</td>
#     </tr>
#   </tbody>
# </table>
# <br>The necessary summary statistics for these data<br>
#                             $$M_A = {83.5}$$
#                             $${\sigma} = {32.26}$$
#                             $$n = {10}$$<br><br>
# Calculate the standard error <br>
#                             $$\sigma_M = \frac{\sigma}{\sqrt{N}}$$ <br>
#                             $$\sigma_M = \frac{32.26}{\sqrt10}$$ <br>
#                             $$\sigma_M = \frac{32.26}{3.16}$$ <br>
#                             $$\sigma_M = {10.21}$$ <br><br>
#                             Calculate $z_{obt}$ <br>
#                             $$z_{obt} = {\frac{M - \mu}{\sigma_M}}$$ <br>
#                             $$z_{obt} = \frac{83.5 - 58}{10.21}$$ <br>
#                             $$z_{obt} = \frac{25.5}{10.21}$$ <br>
#                             $$z_{obt} = {2.5}$$ <br><br>
#                             Calculate Cohen's d for effect size <br>
#                             $$d = \frac{M - \mu}{\sigma}$$ <br>
#                             $$d = \frac{83.5 - 58}{32.26}$$ <br>
#                             $$d = \frac{25.5}{32.26}$$ <br>
#                             $$d = {0.79}$$ <br><br>
# The decision criteria: <br><br>
# $z_{crit} = {-2.33}, \alpha_{one-tailed} = {0.01}$<br><br>
# The results: <br><br>
# fail to reject the null hypothesis, results not significant, z = 2.5, p > 0.01, d = 0.79<br><br>
