# %% [raw]
# ---
# title: Test
# author: Ben
# format:
#   html:
#     html-math-method: mathjax
#     code-fold: true
#     axe:
#       output: console
#     self-contained-math: false
#     embed-resources: true
#
# ---

# %%
#| echo: false
#| output: asis
from stats_project import RandomData

RandomData(groups = 1, n = 7).one_sample_t_test()
# Out:
# Given the following data, is the mean of $Group_A$ significantly greater than ${31}$?  Use a ${1}$ tailed-test with $\alpha = {0.01}$ <br><br>
# <style type="text/css">
# </style>
# <table id="T_ed0e7">
#   <thead>
#     <tr>
#       <th id="T_ed0e7_level0_col0" class="col_heading level0 col0" >A</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ed0e7_row0_col0" class="data row0 col0" >20</td>
#     </tr>
#     <tr>
#       <td id="T_ed0e7_row1_col0" class="data row1 col0" >12</td>
#     </tr>
#     <tr>
#       <td id="T_ed0e7_row2_col0" class="data row2 col0" >7</td>
#     </tr>
#     <tr>
#       <td id="T_ed0e7_row3_col0" class="data row3 col0" >13</td>
#     </tr>
#     <tr>
#       <td id="T_ed0e7_row4_col0" class="data row4 col0" >19</td>
#     </tr>
#     <tr>
#       <td id="T_ed0e7_row5_col0" class="data row5 col0" >15</td>
#     </tr>
#     <tr>
#       <td id="T_ed0e7_row6_col0" class="data row6 col0" >14</td>
#     </tr>
#   </tbody>
# </table>
# ...
