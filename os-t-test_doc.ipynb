# %% [raw]
# ---
# title: Hypothesis Testing with One-Sample *t*-tests
# subtitle: PSY 241
# format:
#   html:
#     html-math-method: mathjax
#     code-fold: true
#     axe:
#       output: console
#     self-contained-math: true
#     embed-resources: true
#
# ---

# %%
#| echo: false
import importlib
import stats_project # Replace with your module name

importlib.reload(stats_project)
from stats_project import RandomData # Re-import the specific class

# %%
#| echo: false
#| output: asis
from stats_project import RandomData

RandomData(groups = 1, n = 8).one_sample_t_test()
# Out:
# Given the following data, is the mean of $Group_A$ significantly different from ${17}$?  Use a ${2}$ tailed-test with $\alpha = {0.01}$ <br><br>
# <style type="text/css">
# </style>
# <table id="T_8da12">
#   <thead>
#     <tr>
#       <th id="T_8da12_level0_col0" class="col_heading level0 col0" >A</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8da12_row0_col0" class="data row0 col0" >27</td>
#     </tr>
#     <tr>
#       <td id="T_8da12_row1_col0" class="data row1 col0" >21</td>
#     </tr>
#     <tr>
#       <td id="T_8da12_row2_col0" class="data row2 col0" >19</td>
#     </tr>
#     <tr>
#       <td id="T_8da12_row3_col0" class="data row3 col0" >23</td>
#     </tr>
#     <tr>
#       <td id="T_8da12_row4_col0" class="data row4 col0" >27</td>
#     </tr>
#     <tr>
#       <td id="T_8da12_row5_col0" class="data row5 col0" >18</td>
#     </tr>
#     <tr>
#       <td id="T_8da12_row6_col0" class="data row6 col0" >21</td>
#     </tr>
#     <tr>
# ...
